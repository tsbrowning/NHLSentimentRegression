# %% [markdown]
# Need to look over which libraries to use for seintiment analysis.
# Plan on comparing token based, tweet based, and sentence based sentiment analysis.
#
# Example line:
#
# 2021-12-02 18:19:51-05:00	Alex Ovechkin	The 2022 #CapsCanineCalendar is Ovi and Blake approved!!! Get your copy today at https://t.co/UNNXR0Ex7J&lt;https://t.co/fgZyeKhwWh&gt; or at @ShopMedStarCaps or @TeamShopAtCOA – join us in supporting @WTARescue and @MSEFndn https://t.co/88D04jW0oV
# ![image.png](attachment:image.png)

# %%
import csv
import re
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import time


lemmatizer = WordNetLemmatizer()

start = time.time()
handle = input('Twitter handle: ')
tweets = f'./data/{handle}.csv'
with open(tweets, encoding = 'utf-8', errors='false') as csv_file:
    outfile = f'./data/{handle}preprocessed.csv'
    with open(outfile, 'w', encoding= 'utf-8') as w:
        writer = csv.writer(w)
        csv_reader = csv.reader(csv_file, delimiter='\t')
        count = 0
        for row in csv_reader:
            #print(row[2], '****\n\n****')
            if count == 0:
                pass
                count += 1
            else:
                date = row[0]
                player = row[1]
                text1 = row[2]
                #print(text)
                ##break string into list of tokens
                text = text1.split(' ')
                
                for word in text:
                    
                    
                    if word.startswith('@'):
                        #replace with <USERNAME>?
                        #print(type(text))
                        #print(word)
                        text1 = re.sub(word, 'USERNAME', text1)
                        #print(text1)
                    if word.startswith('https'):
                        #replace with <URL>\
                        text1 = re.sub(word, 'URL', text1)
                        #continue
                    if word.isnumeric():
                        #replace with <NUM>?
                        #re.sub(word, 'NUM', text)
                        continue
                    #filter for punct
                        
                    
                print(text1, '**\n**')
                count += 1
                

            
    
end = time.time()
clock = end - start
print('processing time: ', clock)
# Out:
# Twitter handle: ovi8
# The 2022 #CapsCanineCalendar is Ovi and Blake approved!!! Get your copy today at URL or at USERNAME or USERNAME – join us in supporting USERNAME and USERNAME URL **
# **
# 🏆 You took the biggest step!!! Congrats USERNAME  Make DC Proud !!🍾🍻 URL **
# **
# Great to be part of the first USERNAME Legends collection!! If u still want to try to get one go to the link below!
# https://t.co/N3iMGDlXur URL **
# **
# Good luck and see you guys soon in DC!! URL **
# **
# Very proud to be a USERNAME Legend with USERNAME and the other sporting icons in this NFT collection 🙌  u guys will love the artwork by USERNAME
#
# Mint is Nov 4 on USERNAME URL **
# **
# See you tomorrow for breakfast babe!!!! URL **
# **
# I am teaming up with USERNAME and artist USERNAME to bring my #NFT Collection to my fans!! Sign up on URL and get ready for the drop Sunday, August 8th!! URL **
# **
# My first NFT drop coming soon with USERNAME chain and USERNAME !!! URL **
# **
# I’M BACK DC !!!!! #ALLCAPS URL **
# **
# Thx for support babes....you are the best!! enjoy the USERNAME pizza!!!!! ))) URL **
# **
# Taking my USERNAME skills 2 the hoop w/ USERNAME + USERNAME new USERNAME USERNAME #basketball game The Court!!! its 1st on USERNAME but for USERNAME u can make it on wishlist now! &gt;&gt;https://t.co/TRB7nnEDib URL **
# **
# 100 percent health is most important Hank ! My family wish the best for you and hope to see you soon!!! 🙏 URL **
# **
# **
# Бегаем!готовимся)))) http://t.co/8AhULSwhal **
# **
# What is love?????can u tell me?!?!?))))hahaha **
# **
# frizi7  USERNAME  USERNAME !!best time!!! http://t.co/dE1mdEGfsW **
# **
# USERNAME happy birthday man!!!!best of luck to u!!! **
# **
# U play in this game😃?who wanna be in my clan?)))#clash of clans http://t.co/x8qDvrfo9T **
# **
# Боже мооой!!!#пробки!!!!!👿👿 http://t.co/IGzthKHGae **
# **
# Отдых!!!))) http://t.co/hO4OIfFqn0 **
# **
# )))) http://t.co/pTtpkzvNSB **
# **
# O yes babe!!!#отдых http://t.co/o0P70PmAg6 **
# **
# U stil #1!!!#messi u my champion!!!!!!!bad luck!!!!u the best!!! http://t.co/00cGrPAEXW **
# **
# #romantic only in Moscow !!!! http://t.co/dVEMF825Tw **
# **
# #баста!)))спасибо Максу за прекрасное время!!!! http://t.co/gqCcNUZYoy **
# **
# #Уважуха!!!!!!!!!!!!!!!!!!! http://t.co/kTmF1qcQ1i **
# **
# 5-0?!?!?!?wow......... http://t.co/V2oR1NFf8M **
# **
# sokolik_13 and USERNAME i ia spor viigral!!hahaha http://t.co/LWukFPT2qt **
# **
# Pirojkov jiga !!!))) http://t.co/SAP55USniG **
# **
# Arthurpirozhkov i best)))hahaha http://t.co/LfFxmNgmRJ **
# **
# My boooooy!!!!!!!#g65 http://t.co/2cP8nA7FHK **
# **
# С днем рождения папа!!!счастья и самого главное огромного ЗДОВЬЯ!!! http://t.co/orbW1ku4Pv **
# **
# Любим,верим ребята!!!!!только победа!!!! http://t.co/tYGdli33GC **
# **
# 51))) http://t.co/FetMcsrFzG **
# **
# Awards in Vegas!with varly!!! http://t.co/ew1NpwSINq **
# **
# Awards!!! http://t.co/su5O7kMLWN **
# **
# Just do it)))hahaah. Maybe u will get it one day!!!! http://t.co/oAsJ3KDYmy **
# **
# Как хорошо знать таких людей USERNAME timatiofficial согласен!!!?))))ahaha http://t.co/QENMImCvNj **
# **
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-2c43925fa190> in <module>
#      37                         #print(type(text))
#      38                         #print(word)
# ---> 39                         text1 = re.sub(word, 'USERNAME', text1)
#      40                         #print(text1)
#      41                     if word.startswith('https'):
#
# ~/anaconda3/lib/python3.8/re.py in sub(pattern, repl, string, count, flags)
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#     211
#     212 def subn(pattern, repl, string, count=0, flags=0):
#
# ~/anaconda3/lib/python3.8/re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#     306         if len(_cache) >= _MAXCACHE:
#
# ~/anaconda3/lib/python3.8/sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# --> 764         p = sre_parse.parse(p, flags)
#     765     else:
#     766         pattern = None
#
# ~/anaconda3/lib/python3.8/sre_parse.py in parse(str, flags, state)
#     960     if source.next is not None:
#     961         assert source.next == ")"
# --> 962         raise source.error("unbalanced parenthesis")
#     963
#     964     if flags & SRE_FLAG_DEBUG:
#
# error: unbalanced parenthesis at position 17
